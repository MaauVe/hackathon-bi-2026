# %% [markdown]
# # Librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Hoja Fraccionamientos

# %%
df_Fraccionamientos= pd.read_csv("..\\data\\processed\\fraccionamientos.csv", encoding="latin1")
print(df_Fraccionamientos.head(5))
# Out:
#    Id_fraccionamiento  Clave Fraccionamiento  NoLotes
# 0                   5     RO        El Roble      122
# 1                   6   AL-I         Alamo 1      217
# 2                   7  AL-II         Alamo 2      132
# 3                   8     LA         La Joya      414
# 4                   9    HVN     Valle Norte        0

# %% [markdown]
# ## Hoja Lotes

# %%
df_Lotes = pd.read_csv("../data/processed/lotes.csv", encoding="latin1")
print(df_Lotes.head(5))
# Out:
#    id_lote  Fraccionamiento    ClaveLote manzana
# 0        2                5   RO-6-03-10       6
# 1        3                5   RO-8-01-01       8
# 2        4                5  RO-10-01-02      10
# 3        5                5   RO-1-02-04       1
# 4        6                5   RO-1-03-03       1

# %% [markdown]
# ## Hoja Viviendas

# %%
df_Viviendas = pd.read_csv("../data/processed/viviendas.csv", encoding="latin1")
print(df_Viviendas.head(5))
# Out:
#    id    clave manzana lote  fraccionamiento_id  user_id created_at  \
# 0   1   FI-2-0       2    0                  12        4   8/8/2025
# 1   2   FI-1-1       1    1                  12        5   8/8/2025
# 2   3  FI-1-8a       1   8a                  12        6   8/8/2025
# 3   4  FI-1-8B       1   8B                  12        7   8/8/2025
# 4   5  FI-1-8E       1   8E                  12        8   8/8/2025
#
#   updated_at  uso_id  saldo_deudor  saldo_favor
# 0  8/22/2025       1             0            0
# 1   8/8/2025       1             0            0
# 2   8/8/2025       1             0            0
# 3   8/8/2025       1             0            0
# 4   8/8/2025       1             0            0

# %% [markdown]
# ## Hoja Periodos

# %%
df_Periodos = pd.read_csv("../data/processed/periodos.csv", encoding="latin1")
print(df_Periodos.head(5))
# Out:
#    Id   año messem  sem     finicio        ffin
# 0   1  2011      S    1  02/01/2011  08/01/2011
# 1   2  2011      S    2  09/01/2011  15/01/2011
# 2   3  2011      S    3  16/01/2011  22/01/2011
# 3   4  2011      S    4  23/01/2011  29/01/2011
# 4   5  2011      S    5  30/01/2011  05/02/2011

# %% [markdown]
# ## Hoja Consumo de Agua

# %%
df_Consumo_de_Agua = pd.read_csv("../data/processed/consumo_agua.csv", encoding="latin1")
print(df_Consumo_de_Agua.head(5))
# Out:
#    Id_detalleordencompra  id_ordencompra  cantidad  \
# 0                  15658            3843       1.0
# 1                  15660            3843       1.0
# 2                  15672            3843       1.0
# 3                  15683            3843       1.0
# 4                  15692            3843       1.0
#
#                                               clave  \
# 0                   CONSUMO AGUA POTABLE CUOTA FIJA
# 1  CONSUMO AGUA POTABLE SERVICIO MEDIDO > 30  < =50
# 2  CONSUMO AGUA POTABLE SERVICIO MEDIDO > 30  < =50
# 3  CONSUMO AGUA POTABLE SERVICIO MEDIDO > 30  < =50
# 4  CONSUMO AGUA POTABLE SERVICIO MEDIDO > 30  < =50
#
#                             descripcion     TOTAL  \
# 0       CONSUMO AGUA POTABLE CUOTA FIJA  596.4162
# 1  CONSUMO AGUA POTABLE SERVICIO MEDIDO  445.7700
# 2  CONSUMO AGUA POTABLE SERVICIO MEDIDO  644.7800
# 3  CONSUMO AGUA POTABLE SERVICIO MEDIDO  345.6300
# 4  CONSUMO AGUA POTABLE SERVICIO MEDIDO  456.0800
#
# ...

# %% [markdown]
# ## Hoja Reporte de Ingresos Egresos

# %%
df_Reporte_Ingresos_Egresos = pd.read_csv("../data/processed/reporte_ingresos_egresos.csv", encoding="latin1")
print(df_Reporte_Ingresos_Egresos.head(5))
# Out:
#    id_detallecheque  ccostos       Fecha  id_cuenta  \
# 0             49198       40  31/08/2010      965.0
# 1             51935       19  30/01/2010     1027.0
# 2             51938       19  30/01/2010     1027.0
# 3             51939       19  30/01/2010     1027.0
# 4             51957       19  26/02/2010     1027.0
#
#                                concepto Clasificacion   entra     sale  \
# 0                      PAGO CUOTAS IMSS        BANCOS     0.0  1364.82
# 1                DEPOSITO AGUA / 13 ENE        BANCOS   850.0     0.00
# 2  DEPOSITO INTERESES CLIENTE  / 29 ENE        BANCOS  3653.5     0.00
# 3  DEPOSITO INTERESES CLIENTE  / 29 ENE        BANCOS  3406.5     0.00
# 4                   DEPOSITO AGUA 4-FEB        BANCOS  1250.0     0.00
#
#                tipomov
# 0  COMISION BANCARIAES
# 1             DEPOSITO
# 2             DEPOSITO
# 3             DEPOSITO
# 4             DEPOSITO

# %%
print(df_Reporte_Ingresos_Egresos.columns)
# Out:
# Index(['id_detallecheque', 'ccostos', 'Fecha', 'id_cuenta', 'concepto',
#        'Clasificacion', 'entra', 'sale', 'tipomov'],
#       dtype='object')

# %%
print(df_Reporte_Ingresos_Egresos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130508 entries, 0 to 130507
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_detallecheque  130508 non-null  int64
#  1   ccostos           130508 non-null  int64
#  2   Fecha             130506 non-null  object
#  3   id_cuenta         130170 non-null  float64
#  4   concepto          128389 non-null  object
#  5   Clasificacion     47920 non-null   object
#  6   entra             130508 non-null  float64
#  7   sale              130508 non-null  float64
#  8   tipomov           130508 non-null  object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 9.0+ MB
# None

# %% [markdown]
# # Perfilado de Datos

# %% [markdown]
# ## Fraccionamientos

# %%
print("Suma de los datos nulos")
print(df_Fraccionamientos.isnull().sum())

print("\n Suma de los datos duplicados")
print(df_Fraccionamientos.duplicated().sum())
# Out:
# Suma de los datos nulos
# Id_fraccionamiento    0
# Clave                 0
# Fraccionamiento       0
# NoLotes               0
# dtype: int64
#
#  Suma de los datos duplicados
# 0

# %%
print("Suma de los datos nulos")
print(df_Lotes.isnull().sum())

print("\n Suma de los datos duplicados")
print(df_Lotes.duplicated().sum())
# Out:
# Suma de los datos nulos
# id_lote            0
# Fraccionamiento    0
# ClaveLote          0
# manzana            0
# dtype: int64
#
#  Suma de los datos duplicados
# 0

# %%
print("Suma de los datos nulos")
print(df_Viviendas.isnull().sum())

print("\n Suma de los datos duplicados")
print(df_Viviendas.duplicated().sum())
# Out:
# Suma de los datos nulos
# id                    0
# clave                 0
# manzana               1
# lote                  1
# fraccionamiento_id    0
# user_id               0
# created_at            0
# updated_at            0
# uso_id                0
# saldo_deudor          0
# saldo_favor           0
# dtype: int64
#
#  Suma de los datos duplicados
# 0

# %%
print("Suma de los datos nulos")
print(df_Periodos.isnull().sum())

print("\n Suma de los datos duplicados")
print(df_Periodos.duplicated().sum())
# Out:
# Suma de los datos nulos
# Id         0
# año        0
# messem     0
# sem        0
# finicio    0
# ffin       0
# dtype: int64
#
#  Suma de los datos duplicados
# 0

# %%
print("Suma de los datos nulos")
print(df_Consumo_de_Agua.isnull().sum())

print("\n Suma de los datos duplicados")
print(df_Consumo_de_Agua.duplicated().sum())
# Out:
# Suma de los datos nulos
# Id_detalleordencompra    0
# id_ordencompra           0
# cantidad                 0
# clave                    0
# descripcion              0
# TOTAL                    0
# subcc                    0
# Fpago                    0
# lote                     0
# PERIODO                  0
# dtype: int64
#
#  Suma de los datos duplicados
# 0

# %%
print("Suma de los datos nulos")
print(df_Reporte_Ingresos_Egresos.isnull().sum())

print("\n Suma de los datos duplicados")
print(df_Reporte_Ingresos_Egresos.duplicated().sum())
# Out:
# Suma de los datos nulos
# id_detallecheque        0
# ccostos                 0
# Fecha                   2
# id_cuenta             338
# concepto             2119
# Clasificacion       82588
# entra                   0
# sale                    0
# tipomov                 0
# dtype: int64
#
#  Suma de los datos duplicados
# 0

# %% [markdown]
# # Limpieza
